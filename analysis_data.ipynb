# %%
import pandas as pd

# %% [markdown]
# # Train dataset

# %%
train_df = pd.read_csv('data/train.csv')

# %%
train_df.head()
# Out:
#                                                 text  label check
# 0                                    Bấp bênh vl thế      1  True
# 1  Thấy chán ad page này kiến thức thì nông cản c...      1   NaN
# 2       Giang Giang Đỗ Thị Ngọc Hà trend mới kìa kìa      0   NaN
# 3  đcm 😒 sau có con cho hút cỏ chữa bệnh chứ đéo ...      1   NaN
# 4                                 Má nứng quá aiu ơi      1  True

# %%
len(train_df)
# Out:
# 47954

# %%
train_df['label'].value_counts().plot(kind='bar', title='Distribution of the labels')
# Out:
# <Axes: title={'center': 'Distribution of the labels'}, xlabel='label'>

# %%
train_df.text.apply(lambda x: len(x.split())).describe()
# Out:
# count    47954.000000
# mean        30.894211
# std         35.711484
# min          1.000000
# 25%          8.000000
# 50%         16.000000
# 75%         39.000000
# max        452.000000
# Name: text, dtype: float64

# %%
train_df.text.apply(lambda x: len(x.split())).sum()
# Out:
# 1481501

# %%
train_df.text.apply(lambda x: len(x.split())).plot(kind='hist', bins= 100, title='Histogram of the number of words in the text', figsize=(10, 5))
# Out:
# <Axes: title={'center': 'Histogram of the number of words in the text'}, ylabel='Frequency'>

# %%
train_df.text.apply(lambda x: len(x.split())).plot(kind='box', title='Box plot of the number of words in the text', figsize=(10, 5), ylabel='Number of words')
# Out:
# <Axes: title={'center': 'Box plot of the number of words in the text'}, ylabel='Number of words'>

# %% [markdown]
# # Val dataset

# %%
val_df = pd.read_csv('data/val.csv')

# %%
val_df.head()
# Out:
#                                                 text  label check
# 0  Cs cha , Cs con , Rận cha, Rận con ...ai đúng ...      1   NaN
# 1                             Long Duy Đào cái tội ớ      0   NaN
# 2                                  Nói gì tào lao kg      1   NaN
# 3                    Chả làm gì cũng có fan cứng =))      0   NaN
# 4  Sao lại cứ đến nụ cười . lên không nghe rõ lời...      0  True

# %%
len(val_df)
# Out:
# 5475

# %%
val_df.label.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
val_df.text.apply(lambda x: len(x.split())).describe()
# Out:
# count    5475.000000
# mean       31.536621
# std        36.478204
# min         1.000000
# 25%         9.000000
# 50%        16.000000
# 75%        40.000000
# max       371.000000
# Name: text, dtype: float64

# %%
val_df.text.apply(lambda x: len(x.split())).plot(kind='hist', bins= 100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Test dataset

# %%
test_df = pd.read_csv('data/test.csv')

# %%
test_df.head()
# Out:
#                                                 text  label check
# 0  Từ lúc mấy bro cmt cực kì cl gì đấy là rất khó...      1   NaN
# 1                Nghe trần dần thấy cười đau cả bụng      0   NaN
# 2  Idol tui có khác. Phải v chứ ai như cái con ph...      1   NaN
# 3                          Cảnh Sát GiựT Tiền = CSGT      1   NaN
# 4                     Ông đi đâu mà lạc sang đây đây      0   NaN

# %%
test_df.label.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
test_df.text.apply(lambda x: len(x.split())).describe()
# Out:
# count    6810.000000
# mean       23.190015
# std        29.824936
# min         1.000000
# 25%         7.000000
# 50%        12.000000
# 75%        25.000000
# max       411.000000
# Name: text, dtype: float64

# %%
test_df.text.apply(lambda x: len(x.split())).plot(kind='hist', bins= 100)
# Out:
# <Axes: ylabel='Frequency'>
